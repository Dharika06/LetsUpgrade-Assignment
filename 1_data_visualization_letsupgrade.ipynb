# %%
import numpy as np
import pandas as pd
import seaborn as sns
from numpy.random import randn, randint, uniform, sample

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.arange(0,10)
y=x*x
plt.plot(x,y,'r--')

# %%
##Practice exercise: plot a  b:line plot between a and
a=np.arange(40,50)
b=np.arange(50,60)
plt.plot(a,b,'r--')

# %%
# Plot a line plot showing the sales trend in company 1 and 2:

days = [1,2,3,4,5,6,7] #days of d week
sales_1 = [160,150,140,145,175,165,180] #sales of company1
sales_2 = [70,90,160,150,140,145,175]  #sales of company2

plt.subplot(1,2,1)
plt.plot(days,sales_1,'r--')
plt.subplot(1,2,2)
plt.plot(days,sales_2,'g*--')

# %%
# Create a 3 by 3 subplots:

## multiple plots

x = [1,2,3,4]
y1 = [4,3,2,1]
y2 = [10,20,30,40]
y3 = [40,30,20,10]
y4 = [1,2,1,2]
y5 = [40,70,90,70]

plt.subplot(3,3,1)
plt.plot(x,y1,'r--')
plt.subplot(3,3,2)
plt.plot(x,y2,'g*--')
plt.subplot(3,3,3)
plt.plot(x,y3,'bo--')
plt.subplot(3,3,4)
plt.plot(x,y4,'go--')
plt.subplot(3,3,5)
plt.plot(x,y5,'go--')
