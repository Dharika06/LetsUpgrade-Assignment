# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharika06/LetsUpgrade-Assignment/blob/main/2_Data_Visualisation_letsupgrade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  1.422355 -0.681921  0.092714  0.029982
# 1  1.300398 -0.387780 -0.132947 -0.578707
# 2  1.197116 -0.857794 -0.340651  1.126705
# 3  2.547594 -0.363341  0.582409  1.247336
# 4  0.381779 -0.126218 -0.580990 -0.076652
# 5 -0.923202 -0.431407 -0.312131 -1.804295
# 6 -1.071038  0.210078 -0.901490 -0.558111
# 7  0.474964 -2.306843  0.599824 -1.533350
# 8 -1.255849 -0.986380  1.027292 -1.123742
# 9  0.075500  0.460680 -1.543653 -0.241846

# %%
## Create a dataframe with 10rows on random numbers and 4 columns, (columns labelled as a,b,c,d) and plot a bar chart.
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])

df.plot.bar();

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
df = iris

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')
